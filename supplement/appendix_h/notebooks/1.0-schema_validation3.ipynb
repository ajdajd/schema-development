# %% [markdown]
# # Data Snapshot Metadata Schema Validation 3
#
# ## Full run: complete Schema v1.2
#
# Calibration is complete. This run supplies the complete generated Schema v1.2
# and the same snapshot directory used by Validation 2. The first three code
# cells are local preflight only; the final cell makes the live API calls.
# Successful results are resumable by snapshot filename.

# %%
from schema_development.paths import ROOT
from schema_development.validation3 import run_validation

# %%
METADATA_DIR = ROOT / "data/source/heldout/metadata"
SNAPSHOTS_DIR = ROOT / "data/source/heldout/snapshots"
CONFIG_PATH = ROOT / "src/schema_development/validation3/config/default.json"
RESULTS_PATH = (
    ROOT / "runs/appendix_h/results.jsonl"
)
ERRORS_PATH = (
    ROOT / "runs/appendix_h/errors.jsonl"
)
SLEEP_SECONDS = 0.2
EXCLUDED_SCHEMA_FIELDS = ()
SNAPSHOT_FILE_NAMES = None

# %%
run_arguments = {
    "snapshots_dir": SNAPSHOTS_DIR,
    "metadata_dir": METADATA_DIR,
    "results_path": RESULTS_PATH,
    "errors_path": ERRORS_PATH,
    "config_path": CONFIG_PATH,
    "snapshot_file_names": SNAPSHOT_FILE_NAMES,
    "excluded_schema_fields": EXCLUDED_SCHEMA_FIELDS,
    "sleep_seconds": SLEEP_SECONDS,
}
run_arguments

# %%
summary = run_validation(**run_arguments)
summary

# %%
from schema_development.paths import ROOT
from schema_development.validation1 import run_validation

# %%
# Calibration run
SNAPSHOTS_DIR = ROOT / "data/source/heldout/snapshots"
METADATA_DIR = ROOT / "data/source/heldout/metadata"
SCHEMA_PATH = ROOT / "schemas/Data Snapshot Metadata Schema v1.1.md"
CONFIG_PATH = ROOT / "src/schema_development/validation1/config/default.json"
RESULTS_PATH = ROOT / "runs/validation1/results.jsonl"
ERRORS_PATH = ROOT / "runs/validation1/errors.jsonl"
SLEEP_SECONDS = 0.2

# %%
run_arguments = {
    "snapshots_dir": SNAPSHOTS_DIR,
    "metadata_dir": METADATA_DIR,
    "schema_path": SCHEMA_PATH,
    "results_path": RESULTS_PATH,
    "errors_path": ERRORS_PATH,
    "config_path": CONFIG_PATH,
    "sleep_seconds": SLEEP_SECONDS,
}
run_arguments

# %%
summary = run_validation(**run_arguments)
summary
